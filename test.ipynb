# %%
import pickle
from PIL import Image

import io

# %%
import pandas as pd

# %%
df = pd.read_parquet('all_rows.pqt')

# %%
df[df.name.str.startswith('Николай Гоголь')]
# Out:
#           id                                   link  \
# 1226  983805  https://www.labirint.ru/books/983805/
# 7995  577332  https://www.labirint.ru/books/577332/
# 8053  634514  https://www.labirint.ru/books/634514/
# 8066  628288  https://www.labirint.ru/books/628288/
# 8139  638419  https://www.labirint.ru/books/638419/
# 8150  363272  https://www.labirint.ru/books/363272/
# 8175  832395  https://www.labirint.ru/books/832395/
# 8211  993449  https://www.labirint.ru/books/993449/
# 8315  660288  https://www.labirint.ru/books/660288/
# 8344  843505  https://www.labirint.ru/books/843505/
# 8435  863651  https://www.labirint.ru/books/863651/
# 8650  372298  https://www.labirint.ru/books/372298/
#
#                                                    name   rate  \
# 1226     Николай Гоголь: Вечера на хуторе близ Диканьки   9.38
# 7995                       Николай Гоголь: Мертвые души   8.38
# 8053                   Николай Гоголь: Женитьба. Игроки   9.50
# ...
