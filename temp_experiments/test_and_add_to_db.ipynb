# %% [markdown]
# ## Get by index

# %%
import pandas as pd 
import aiopg
  
  
DSN = 'dbname=test_db user=test host=localhost password=test port=5430'
  
async def create_db_pool():
    return await aiopg.create_pool(DSN)
  
db_pool = await create_db_pool()   

  
async with db_pool.acquire() as conn:
    async with conn.cursor() as cur:
        await cur.execute('''
            select count(*) from all_rows;
        ''')

        ret = await cur.fetchall()

        print(ret)

db_pool.close()

await db_pool.wait_closed()
# Out:
# [(12342,)]

# %% [markdown]
# ## Create database

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

engine = create_engine('postgresql://test:test@localhost:5430/test_db', echo=False)

df = pd.read_parquet(os.path.join('data', 'tf-idf', 'all_rows.pqt'))

# %%
df.reset_index().to_sql(name='all_rows', con=engine, if_exists='replace')

from sqlalchemy import text

with engine.connect() as conn:
    print(conn.execute(text("select * from all_rows limit 5")).fetchall())

#.execution_options(autocommit=True)
# Out:
# [(0, 0, 451006, 'https://www.labirint.ru/books/451006/', 'Роберт Стивенсон: Остров Сокровищ', 9.38, ' Знаменитый роман Роберта Льюиса Стивенсона в сопровождении подробного историко-бытового комментария, посвященного морскому делу в Англии XVIII века  ... (1255 characters truncated) ... канаты в натуральную величину— Объемный бриг, меняющий галсы— План обороны блокгауза— Подробные биографии знаменитых пиратов— Настоящая черная метка.', 'Есть у меня одна страсть. По нынешним временам, разорительная для семейного бюджета. Не могу спокойно даже смотреть на книги. Книжные магазины обхожу ... (5714 characters truncated) ... екательное плавание по волнам прошлого. Чтобы найти свой Остров Сокровищ".\n;\nТекст в классическом переводе Н. Чуковского печатается без сокращений.'), (1, 1, 786953, 'https://www.labirint.ru/books/786953/', 'Жюль Верн: Вокруг света в восемьдесят дней', 8.26, '"Вокруг книги" - это лучшие произведения мировой литературы с подробным историко-бытовым комментарием.Комментарии расположены на тематических разворо ... (1134 characters truncated) ... нская пагода- Советы опытных путешественников XIX века- Винтовой пароход и американский поезд в деталях- Игра "Путешествие вокруг света с Нелли Блай"', 'Позволю себе не разделить восторга предыдущих ораторов относительно того, что Лабиринт превзошел сам себя! Это 14-я книга данной серии в моей коллекц ... (1753 characters truncated) ... но еще больше - оставить себе! :) Хочу поделиться несколькими фотографиями, но они, как уже замечено, не отображают прямо всего впечатления от книги.'), (2, 2, 840898, 'https://www.labirint.ru/books/840898/', 'Тур Хейердал: Экспедиция "Кон-Тики"', 8.33, 'Отважный человек, нестандартно мыслящий, самоотверженно следующий своим идеям, - так можно характеризовать Тура Хейердала. Он - автор этой книги, вдо ... (499 characters truncated) ... ометров за 101 день. Захватывающее приключение на просторах океана и сложная и опасная подготовка к нему - всё это легендарная Экспедиция "Кон-Тики".', 'Наверное, впервые вижу книгу, про которую хочется сказать "понравится каждому". По сути это шикарно оформленный рассказ норвежского путешественника Т ... (878 characters truncated) ... зрослым, так и детям. Я в предвкушении и в нетерпении приступить к чтению.\nОгромная благодарность создателям таких книг! Восторгу моему нет предела.'), (3, 3, 614463, 'https://www.labirint.ru/books/614463/', 'Артур Дойл: Приключения Шерлока Холмса', 9.06, 'Интерактивное комментированное издание рассказов о самом известном детективе всех времен и народов. Эта книга - настоящее сокровище для любителей дет ... (1067 characters truncated) ... ый кэб- История лондонской полиции- Личные дела главных персонажей- Архив Холмса- Досье дерзких преступников и талантливых сыщиковДля детей 9-12 лет.', 'Фотографии сделаны на выставке. Фотографировала наспех, к сожалению. На самом деле книга с полиграфической точки зрения гораздо лучше, материал и илл ... (2922 characters truncated) ... атривали. \r\nПотрясающая книга! У нас есть уже остров сокровищ из этой серии. Приключения Шерлока Холмса достойно дополнили коллекцию отличных книг!'), (4, 4, 869738, 'https://www.labirint.ru/books/869738/', 'Артур Дойл: Записки о Шерлоке Холмсе', 9.07, 'В книгу вошли пять рассказов Артура Конан Дойла о знаменитом сыщике Шерлоке Холмсе и его верном друге и биографе докторе Уотсоне. Рассказы сопровожда ... (620 characters truncated) ... .- Знаменитые преступления XIX века.- Отпечатки пальцев сквозь лупу детектива.- Шпионские страсти.- Путеводитель по всем делам прославленного сыщика.', 'Вторая книга, наконец-то! Уже и не чаяли, как говорится. Шерлок Холмс - это про эстетику, внимание к деталям и стиль. Изучить ее как следует пока еще ... (715 characters truncated) ... орг! Моя коллекция изданий о Холмсе пополнилась очередным шедевром. Благодарю создателей! А можно попросить когда -нибудь Агату Кристи также сделать?')]
